# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: streamlit in c:\users\1412r\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (1.33.0)
# Requirement already satisfied: google-generativeai in c:\users\1412r\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: python-dotenv in c:\users\1412r\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: nltk in c:\users\1412r\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (3.9.1)
# Requirement already satisfied: textblob in c:\users\1412r\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (0.19.0)
# Requirement already satisfied: black in c:\users\1412r\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (19.10b0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (0.8.1b0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (1.7.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (8.5.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (4.2.2)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\1412r\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\1412r\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\1412r\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\1412r\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\1412r\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\1412r\anaconda3\lib\site-packages)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (2.1.6)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (16.0.0)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (10.3.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (4.25.5)
# Requirement already satisfied: packaging<25,>=16.8 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (5.3.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (8.0.4)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (1.23.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (6.1)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\1412r\anaconda3\lib\site-packages (from streamlit->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: pydantic in c:\users\1412r\anaconda3\lib\site-packages (from google-generativeai->-r requirements.txt (line 2)) (2.10.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\1412r\anaconda3\lib\site-packages (from google-generativeai->-r requirements.txt (line 2)) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\1412r\anaconda3\lib\site-packages (from google-generativeai->-r requirements.txt (line 2)) (2.24.0)
# Requirement already satisfied: google-api-python-client in c:\users\1412r\anaconda3\lib\site-packages (from google-generativeai->-r requirements.txt (line 2)) (2.159.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\1412r\anaconda3\lib\site-packages (from google-generativeai->-r requirements.txt (line 2)) (2.17.3)
# Requirement already satisfied: tqdm in c:\users\1412r\anaconda3\lib\site-packages (from google-generativeai->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\1412r\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai->-r requirements.txt (line 2)) (1.25.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\1412r\anaconda3\lib\site-packages (from nltk->-r requirements.txt (line 4)) (2022.3.15)
# Requirement already satisfied: joblib in c:\users\1412r\anaconda3\lib\site-packages (from nltk->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: pathspec<1,>=0.6 in c:\users\1412r\anaconda3\lib\site-packages (from black->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: appdirs in c:\users\1412r\anaconda3\lib\site-packages (from black->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: typed-ast>=1.4.0 in c:\users\1412r\anaconda3\lib\site-packages (from black->-r requirements.txt (line 6)) (1.4.3)
# Requirement already satisfied: attrs>=18.1.0 in c:\users\1412r\anaconda3\lib\site-packages (from black->-r requirements.txt (line 6)) (21.4.0)
# Requirement already satisfied: jinja2 in c:\users\1412r\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\1412r\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: toolz in c:\users\1412r\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (0.11.2)
# Requirement already satisfied: colorama in c:\users\1412r\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit->-r requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\1412r\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\1412r\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\1412r\anaconda3\lib\site-packages (from google-api-core->google-generativeai->-r requirements.txt (line 2)) (1.66.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\1412r\anaconda3\lib\site-packages (from google-api-core->google-generativeai->-r requirements.txt (line 2)) (1.62.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\1412r\anaconda3\lib\site-packages (from google-api-core->google-generativeai->-r requirements.txt (line 2)) (1.69.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\1412r\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai->-r requirements.txt (line 2)) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\1412r\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\1412r\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai->-r requirements.txt (line 2)) (4.7.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\1412r\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\1412r\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 1)) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\1412r\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\1412r\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai->-r requirements.txt (line 2)) (0.4.8)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\1412r\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\1412r\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\1412r\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\1412r\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (1.26.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\1412r\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\1412r\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\1412r\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 1)) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\1412r\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\1412r\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai->-r requirements.txt (line 2)) (4.1.1)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\1412r\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\1412r\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai->-r requirements.txt (line 2)) (0.22.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\1412r\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai->-r requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\1412r\anaconda3\lib\site-packages (from pydantic->google-generativeai->-r requirements.txt (line 2)) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\1412r\anaconda3\lib\site-packages (from pydantic->google-generativeai->-r requirements.txt (line 2)) (0.7.0)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\1412r\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\1412r\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\1412r\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\1412r\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\1412r\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\1412r\anaconda3\lib\site-packages)

# %%
import os
import re
import time

import streamlit as st
import google.generativeai as genai

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# Load necessary NLTK data
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\1412r\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\1412r\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\1412r\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Configure the GenAI API
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    st.error("API key is not set. Please check your .env file.")
genai.configure(api_key=api_key)
# Out:
# 2025-01-23 10:33:53.570
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\1412r\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
# Initialize the generative model and chat history
model = genai.GenerativeModel("gemini-pro")  # gemini-1.5-flash
chat = model.start_chat(history=[])

# %%
# Initialize Streamlit app
st.set_page_config(page_title="Kitchen Recipe Chatbot", layout="centered")
st.header("🍲 Kitchen Recipe Chatbot")

# Define the initial prompt format
input_prompt = """
You are a culinary expert and kitchen assistant, helping users find recipes based on available ingredients.
When a user provides a list of ingredients or asks about a specific dish, respond with a recipe that includes:

1. **Recipe Name** : (Give the name of the recipe with Normal font)
2. **Ingredients**: (list with quantities)
3. **Instructions**: (step-by-step cooking guide)
4. **Additional Tips**: (optional, for preparation or substitutions)

Format the response accordingly and be concise yet thorough.
"""

# Initialize session state for chat history and responses if not set
if "chat_history" not in st.session_state:
    st.session_state["chat_history"] = []
if "bot_responses" not in st.session_state:
    st.session_state["bot_responses"] = []


# Function to preprocess user input text
def preprocess_text(text):
    # Remove all the special characters
    text = re.sub(r"\W", " ", str(text))

    # Remove all single characters
    text = re.sub(r"\s+[a-zA-Z]\s+", " ", text)

    # Remove single characters from the start
    text = re.sub(r"\^[a-zA-Z]\s+", " ", text)

    # Substitute multiple spaces with a single space
    text = re.sub(r"\s+", " ", text, flags=re.I)

    # Remove prefixed 'b'(byte strings)
    text = re.sub(r"^b\s+", "", text)

    # Convert to lowercase
    text = text.lower()

    return text.strip()


# Defining a function to remove stopwords from the review
def remove_stopwords(text):
    stop_words = set(stopwords.words("english"))

    # Split the text into words
    words = text.split()

    # Remove stopwords
    filtered_words = [word for word in words if word not in stop_words]

    # Join the words back into a single string
    return " ".join(filtered_words)


# Defining a function to lemmatize the input text
def lemmatize_input_text(text):
    lemmatizer = WordNetLemmatizer()

    # Tokenize the text into words
    words = [word for word in text.split()]

    # Lemmatize each word
    lemmatized = [lemmatizer.lemmatize(word) for word in words]
    return " ".join(lemmatized)


# preprocessing function to clean the input text
def clean_input_text(text):
    preprocessed_text = preprocess_text(text)
    text_without_stopwords = remove_stopwords(preprocessed_text)
    cleaned_text = lemmatize_input_text(text_without_stopwords)
    return cleaned_text


# Text area input field
user_input = st.text_area(
    "Type your recipe request here:",
    placeholder="Enter ingredients or dish name...",
    key="input",
    height=100,
)
submit_button = st.button("Send")

# Display chat history below the input box
for role, text in st.session_state["chat_history"]:
    if role == "You":
        st.write(f"**{role}:** {text}")
    else:
        st.write(f"**Bot:** {text}")

# Divider for layout organization
st.divider()


# Function to handle retries
def get_bot_response_with_retry(user_input, retries=5, delay=5):
    for attempt in range(retries):
        try:
            # Send prompt + query to model in a single API call
            response_chunks = chat.send_message(
                f"{input_prompt}\n\nUser query: {user_input}", stream=True
            )

            # Collect the response text
            bot_reply = "".join([chunk.text for chunk in response_chunks])
            return bot_reply

        except Exception as e:
            if attempt < retries - 1:
                st.warning(f"Error: {e}. Retrying in {delay} seconds...")

                # Wait before retrying
                time.sleep(delay)
            else:
                st.error(f"Error: {e}. Please try again later.")
                return None


# Extract the recipe name for the filename
def extract_recipe_name(recipe_text):
    # Matching various patterns for a Recipe Name in the response
    match = re.search(r"(Recipe Name[:\-]?\s*)([^\n]+)", recipe_text, re.IGNORECASE)
    if match:
        recipe_name = match.group(2).strip()

        # Clean up the recipe name for use as a filename
        recipe_name = re.sub(r'[\\/*?:"<>|]', "", recipe_name)
        return recipe_name
    else:
        # Log output
        print("Recipe name not found. Using default filename.")
    return "recipe"


# Process user input and get response on form submission
if submit_button and user_input:
    # Clean user input
    cleaned_input = clean_input_text(user_input)

    # Add original user query to chat history
    st.session_state["chat_history"].append(("You", user_input))

    # Get response from Gemini model with retry mechanism using cleaned input
    bot_reply = get_bot_response_with_retry(cleaned_input)

    if bot_reply:
        # Update chat history and bot responses
        st.session_state["chat_history"].append(("Bot", bot_reply))
        # Track bot responses for saving
        st.session_state["bot_responses"].append(bot_reply)

        # Immediately display the bot response after processing
        st.write(f"**Bot:** {bot_reply}")

# Save Button to download recipe as a text file
if st.session_state["bot_responses"]:
    recipe = st.session_state["bot_responses"][-1]
    recipe_name = extract_recipe_name(recipe)
    if " " in recipe_name:
        recipe_name = recipe_name.lstrip().replace(" ", "_") + "_recipe"
    else:
        recipe_name = recipe_name.lstrip() + "_recipe"
    st.download_button(
        label="Save Recipe",
        data=recipe,
        file_name=f"{recipe_name}.txt",
        mime="text/plain",
    )

# Display prompt for first-time users if chat history is empty
if not st.session_state["chat_history"]:
    st.info("Enter a recipe query to start chatting with the bot.")
# Out:
# 2025-01-23 10:34:35.386 Session state does not function when running a script without `streamlit run`
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state.py:408, in SessionState.__getitem__(self, key)
#     407 try:
# --> 408     return self._getitem(widget_id, key)
#     409 except KeyError:
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state.py:453, in SessionState._getitem(self, widget_id, user_key)
#     452 # We'll never get here
# --> 453 raise KeyError
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 92>()
#      89 submit_button = st.button("Send")
#      91 # Display chat history below the input box
# ---> 92 for role, text in st.session_state["chat_history"]:
#      93     if role == "You":
#      94         st.write(f"**{role}:** {text}")
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state_proxy.py:90, in SessionStateProxy.__getitem__(self, key)
#      88 key = str(key)
#      89 require_valid_user_key(key)
# ---> 90 return get_session_state()[key]
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\safe_session_state.py:93, in SafeSessionState.__getitem__(self, key)
#      91 self._yield_callback()
#      92 with self._lock:
# ---> 93     return self._state[key]
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state.py:410, in SessionState.__getitem__(self, key)
#     408     return self._getitem(widget_id, key)
#     409 except KeyError:
# --> 410     raise KeyError(_missing_key_error_message(key))
#
# KeyError: 'st.session_state has no key "chat_history". Did you forget to initialize it? More info: https://docs.streamlit.io/library/advanced-features/session-state#initialization'

# %%
# Initialize Streamlit app
st.set_page_config(page_title='Kitchen Recipe Chatbot', layout="centered")
st.header('🍲 Kitchen Recipe Chatbot')

# Define the initial prompt format
input_prompt = """
You are a culinary expert and kitchen assistant, helping users find recipes based on available ingredients.
When a user provides a list of ingredients or asks about a specific dish, respond with a recipe that includes:

1. **Recipe Name** : (Give the name of the recipe with Normal font)
2. **Ingredients**: (list with quantities)
3. **Instructions**: (step-by-step cooking guide)
4. **Additional Tips**: (optional, for preparation or substitutions)

Format the response accordingly and be concise yet thorough.
"""

# Initialize session state for chat history and responses if not set
if 'chat_history' not in st.session_state:
    st.session_state['chat_history'] = []
if 'bot_responses' not in st.session_state:
    st.session_state['bot_responses'] = []

# Text area input field
user_input = st.text_area("Type your recipe request here:", placeholder="Enter ingredients or dish name...", key="input", height=100)
submit_button = st.button("Send")

# Display chat history below the input box
for role, text in st.session_state['chat_history']:
    if role == "You":
        st.write(f"**{role}:** {text}")
    else:
        st.write(f"**Bot:** {text}")

# Divider for layout organization
st.divider()

# Function to handle retries
def get_bot_response_with_retry(user_input, retries=5, delay=5):
    for attempt in range(retries):
        try:
            # Send prompt + query to model in a single API call
            response_chunks = chat.send_message(f"{input_prompt}\n\nUser query: {user_input}", stream=True)
            
            # Collect the response text and return it
            bot_reply = "".join([chunk.text for chunk in response_chunks])
            return bot_reply
        
        except Exception as e:
            if attempt < retries - 1:
                st.warning(f"Error: {e}. Retrying in {delay} seconds...")
                time.sleep(delay)  # Wait before retrying
            else:
                st.error(f"Error: {e}. Please try again later.")
                return None

# Extract the recipe name for the filename
def extract_recipe_name(recipe_text):
    # Try matching various patterns for "Recipe Name" in the response
    match = re.search(r"(Recipe Name[:\-]?\s*)([^\n]+)", recipe_text, re.IGNORECASE)
    if match:
        recipe_name = match.group(2).strip()

        # Clean up the recipe name for use as a filename
        recipe_name = re.sub(r'[\\/*?:"<>|]', "", recipe_name)
        return recipe_name
    else:
        print("Recipe name not found. Using default filename.")  # Debug output
    return "recipe"

# Process user input and get response on form submission
if submit_button and user_input:
    # Add user query to chat history
    st.session_state['chat_history'].append(("You", user_input))

    # Get response from Gemini model with retry mechanism
    bot_reply = get_bot_response_with_retry(user_input)
    
    if bot_reply:
        # Update chat history and bot responses
        st.session_state['chat_history'].append(("Bot", bot_reply))
        st.session_state['bot_responses'].append(bot_reply)  # Track bot responses for saving

        # Immediately display the bot response after processing
        st.write(f"**Bot:** {bot_reply}")

# Save Button to download recipe as a text file
if st.session_state['bot_responses']:
    recipe = st.session_state['bot_responses'][-1]
    recipe_name = extract_recipe_name(recipe)
    if ' ' in recipe_name:
        recipe_name = recipe_name.lstrip().replace(' ', '_') + '_recipe'
    else:
        recipe_name = recipe_name.lstrip() + '_recipe'
    st.download_button(label="Save Recipe", data=recipe, file_name=f"{recipe_name}.txt", mime="text/plain")

# Display prompt for first-time users if chat history is empty
if not st.session_state['chat_history']:
    st.info("Enter a recipe query to start chatting with the bot.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state.py:408, in SessionState.__getitem__(self, key)
#     407 try:
# --> 408     return self._getitem(widget_id, key)
#     409 except KeyError:
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state.py:453, in SessionState._getitem(self, widget_id, user_key)
#     452 # We'll never get here
# --> 453 raise KeyError
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 29>()
#      26 submit_button = st.button("Send")
#      28 # Display chat history below the input box
# ---> 29 for role, text in st.session_state['chat_history']:
#      30     if role == "You":
#      31         st.write(f"**{role}:** {text}")
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state_proxy.py:90, in SessionStateProxy.__getitem__(self, key)
#      88 key = str(key)
#      89 require_valid_user_key(key)
# ---> 90 return get_session_state()[key]
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\safe_session_state.py:93, in SafeSessionState.__getitem__(self, key)
#      91 self._yield_callback()
#      92 with self._lock:
# ---> 93     return self._state[key]
#
# File ~\anaconda3\lib\site-packages\streamlit\runtime\state\session_state.py:410, in SessionState.__getitem__(self, key)
#     408     return self._getitem(widget_id, key)
#     409 except KeyError:
# --> 410     raise KeyError(_missing_key_error_message(key))
#
# KeyError: 'st.session_state has no key "chat_history". Did you forget to initialize it? More info: https://docs.streamlit.io/library/advanced-features/session-state#initialization'
